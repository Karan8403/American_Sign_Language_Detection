# %%
import tensorflow as tf
import keras
from keras.callbacks import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import *

# %%
traindata = pd.read_csv('sign_mnist_train.csv')

# %%
trainlabel=traindata['label'].values

# %%
traindata.drop('label',inplace=True,axis=1)
trainimages = traindata.values

# %%
trainimages=trainimages.reshape(-1,28,28,1)

# %%
testdata = pd.read_csv('sign_mnist_test.csv')

# %%
testlabel=testdata['label'].values

# %%
testdata.drop('label',inplace=True,axis=1)
testimages = testdata.values

# %%
testimages=testimages.reshape(-1,28,28,1)

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
traingen=ImageDataGenerator(rotation_range=40,zoom_range=0.2,width_shift_range=0.2,height_shift_range=0.2,
                  shear_range=0.2,horizontal_flip=True,rescale=1/255.0,validation_split=0.2)

# %%
traindata_generator = traingen.flow(trainimages,trainlabel,subset='training')
validationdata_generator = traingen.flow(trainimages,trainlabel,subset='validation')

# %%
testgen=ImageDataGenerator(rescale=1/255.0)
testdata_generator = testgen.flow(testimages,testlabel)

# %%
model=Sequential([])

model.add(Conv2D(64,(3,3),activation="relu",input_shape=(28,28,1)))
model.add(BatchNormalization())
# model.add(Conv2D(64,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))
#model.add(Dropout(0.4))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(BatchNormalization())
# model.add(Conv2D(128,(3,3),activation="relu"))
# model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(256,activation="relu"))
model.add(BatchNormalization())
model.add(Dense(26,activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  batch_normalization (Batch  (None, 26, 26, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 13, 13, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 128)       73856
#
#  batch_normalization_1 (Bat  (None, 11, 11, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 128)         0
#  g2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  batch_normalization_2 (Bat  (None, 3200)              12800
#  chNormalization)
#
#  dropout (Dropout)           (None, 3200)              0
#
#  dense (Dense)               (None, 256)               819456
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_1 (Dense)             (None, 26)                6682
#
# =================================================================
# Total params: 915226 (3.49 MB)
# Trainable params: 907930 (3.46 MB)
# Non-trainable params: 7296 (28.50 KB)
# _________________________________________________________________

# %%
# Define a Callback class that stops training once accuracy reaches 97.0%
class myCallback(Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.985):
      print("\nReached 98.5% accuracy so cancelling training!")
      self.model.stop_training = True
callback=myCallback()

# %%
history=model.fit(traindata_generator,epochs=60,validation_data=validationdata_generator,callbacks=[callback])
# Out:
# Epoch 1/60
# 687/687 [==============================] - 23s 21ms/step - loss: 2.3738 - accuracy: 0.2862 - val_loss: 3.5915 - val_accuracy: 0.1568
# Epoch 2/60
# 687/687 [==============================] - 14s 20ms/step - loss: 1.4927 - accuracy: 0.5182 - val_loss: 1.6405 - val_accuracy: 0.4904
# Epoch 3/60
# 687/687 [==============================] - 14s 21ms/step - loss: 1.1597 - accuracy: 0.6166 - val_loss: 1.1498 - val_accuracy: 0.6287
# Epoch 4/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.9663 - accuracy: 0.6802 - val_loss: 3.6222 - val_accuracy: 0.2763
# Epoch 5/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.8399 - accuracy: 0.7209 - val_loss: 3.3742 - val_accuracy: 0.3409
# Epoch 6/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.7726 - accuracy: 0.7390 - val_loss: 2.4222 - val_accuracy: 0.3761
# Epoch 7/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.7017 - accuracy: 0.7643 - val_loss: 0.5887 - val_accuracy: 0.8099
# Epoch 8/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.6741 - accuracy: 0.7730 - val_loss: 1.1751 - val_accuracy: 0.6600
# Epoch 9/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.6069 - accuracy: 0.7969 - val_loss: 0.5395 - val_accuracy: 0.8157
# Epoch 10/60
# 687/687 [==============================] - 13s 20ms/step - loss: 0.5795 - accuracy: 0.8022 - val_loss: 0.9053 - val_accuracy: 0.7053
# Epoch 11/60
# 687/687 [==============================] - 15s 22ms/step - loss: 0.5543 - accuracy: 0.8119 - val_loss: 1.9090 - val_accuracy: 0.5232
# Epoch 12/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.5177 - accuracy: 0.8256 - val_loss: 0.7703 - val_accuracy: 0.7418
# Epoch 13/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.5152 - accuracy: 0.8262 - val_loss: 2.7400 - val_accuracy: 0.4282
# Epoch 14/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.4817 - accuracy: 0.8376 - val_loss: 0.5160 - val_accuracy: 0.8213
# Epoch 15/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.4588 - accuracy: 0.8425 - val_loss: 0.4919 - val_accuracy: 0.8275
# Epoch 16/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.4517 - accuracy: 0.8456 - val_loss: 0.5537 - val_accuracy: 0.8248
# Epoch 17/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.4447 - accuracy: 0.8500 - val_loss: 0.3793 - val_accuracy: 0.8767
# Epoch 18/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.4267 - accuracy: 0.8532 - val_loss: 0.5610 - val_accuracy: 0.8097
# Epoch 19/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.4081 - accuracy: 0.8624 - val_loss: 0.6076 - val_accuracy: 0.8039
# Epoch 20/60
# 687/687 [==============================] - 15s 21ms/step - loss: 0.4120 - accuracy: 0.8601 - val_loss: 0.3055 - val_accuracy: 0.8993
# Epoch 21/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.3797 - accuracy: 0.8721 - val_loss: 0.6136 - val_accuracy: 0.7944
# Epoch 22/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.3835 - accuracy: 0.8693 - val_loss: 0.6223 - val_accuracy: 0.7928
# Epoch 23/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.3844 - accuracy: 0.8700 - val_loss: 0.3235 - val_accuracy: 0.8904
# Epoch 24/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.3617 - accuracy: 0.8752 - val_loss: 0.2524 - val_accuracy: 0.9151
# Epoch 25/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.3560 - accuracy: 0.8783 - val_loss: 0.8121 - val_accuracy: 0.7813
# Epoch 26/60
# 687/687 [==============================] - 15s 21ms/step - loss: 0.3415 - accuracy: 0.8831 - val_loss: 0.3884 - val_accuracy: 0.8767
# Epoch 27/60
# 687/687 [==============================] - 16s 23ms/step - loss: 0.3568 - accuracy: 0.8790 - val_loss: 0.4145 - val_accuracy: 0.8603
# Epoch 28/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.3381 - accuracy: 0.8839 - val_loss: 0.3547 - val_accuracy: 0.8774
# Epoch 29/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.3250 - accuracy: 0.8900 - val_loss: 0.2008 - val_accuracy: 0.9330
# Epoch 30/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.3268 - accuracy: 0.8917 - val_loss: 0.5036 - val_accuracy: 0.8257
# Epoch 31/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.3159 - accuracy: 0.8941 - val_loss: 0.2030 - val_accuracy: 0.9304
# Epoch 32/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.3011 - accuracy: 0.8976 - val_loss: 0.2969 - val_accuracy: 0.9027
# Epoch 33/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.2970 - accuracy: 0.8981 - val_loss: 0.3648 - val_accuracy: 0.8791
# Epoch 34/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2907 - accuracy: 0.9021 - val_loss: 0.5418 - val_accuracy: 0.8308
# Epoch 35/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2812 - accuracy: 0.9036 - val_loss: 0.3689 - val_accuracy: 0.8732
# Epoch 36/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.2946 - accuracy: 0.8995 - val_loss: 0.4748 - val_accuracy: 0.8385
# Epoch 37/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2803 - accuracy: 0.9045 - val_loss: 0.7846 - val_accuracy: 0.7694
# Epoch 38/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2794 - accuracy: 0.9078 - val_loss: 0.4452 - val_accuracy: 0.8583
# Epoch 39/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.2745 - accuracy: 0.9088 - val_loss: 0.2132 - val_accuracy: 0.9286
# Epoch 40/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.2719 - accuracy: 0.9088 - val_loss: 0.2062 - val_accuracy: 0.9321
# Epoch 41/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.2851 - accuracy: 0.9034 - val_loss: 0.1564 - val_accuracy: 0.9454
# Epoch 42/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2693 - accuracy: 0.9073 - val_loss: 0.1544 - val_accuracy: 0.9455
# Epoch 43/60
# 687/687 [==============================] - 18s 26ms/step - loss: 0.2587 - accuracy: 0.9143 - val_loss: 0.4722 - val_accuracy: 0.8503
# Epoch 44/60
# 687/687 [==============================] - 14s 21ms/step - loss: 0.2637 - accuracy: 0.9100 - val_loss: 0.4799 - val_accuracy: 0.8427
# Epoch 45/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2500 - accuracy: 0.9165 - val_loss: 0.1249 - val_accuracy: 0.9599
# Epoch 46/60
# 687/687 [==============================] - 13s 20ms/step - loss: 0.2475 - accuracy: 0.9169 - val_loss: 0.7182 - val_accuracy: 0.7969
# Epoch 47/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2457 - accuracy: 0.9167 - val_loss: 0.2885 - val_accuracy: 0.8989
# Epoch 48/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2452 - accuracy: 0.9171 - val_loss: 0.3528 - val_accuracy: 0.8931
# Epoch 49/60
# 687/687 [==============================] - 15s 21ms/step - loss: 0.2423 - accuracy: 0.9189 - val_loss: 0.1900 - val_accuracy: 0.9392
# Epoch 50/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2315 - accuracy: 0.9222 - val_loss: 0.1921 - val_accuracy: 0.9383
# Epoch 51/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2451 - accuracy: 0.9173 - val_loss: 0.2866 - val_accuracy: 0.9095
# Epoch 52/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2371 - accuracy: 0.9194 - val_loss: 0.1878 - val_accuracy: 0.9410
# Epoch 53/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2377 - accuracy: 0.9196 - val_loss: 0.2695 - val_accuracy: 0.9109
# Epoch 54/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2218 - accuracy: 0.9249 - val_loss: 0.4509 - val_accuracy: 0.8565
# Epoch 55/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2311 - accuracy: 0.9199 - val_loss: 11.4134 - val_accuracy: 0.5937
# Epoch 56/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2246 - accuracy: 0.9240 - val_loss: 0.2665 - val_accuracy: 0.9131
# Epoch 57/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2338 - accuracy: 0.9205 - val_loss: 0.5067 - val_accuracy: 0.8397
# Epoch 58/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2222 - accuracy: 0.9253 - val_loss: 1.6631 - val_accuracy: 0.6421
# Epoch 59/60
# 687/687 [==============================] - 15s 22ms/step - loss: 0.2213 - accuracy: 0.9262 - val_loss: 0.1505 - val_accuracy: 0.9486
# Epoch 60/60
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2145 - accuracy: 0.9275 - val_loss: 0.3506 - val_accuracy: 0.8878

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# <ipython-input-20-3869c0eee6ae>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 97.83881902694702

# %%
history=model.fit(traindata_generator,epochs=100,validation_data=validationdata_generator,callbacks=[callback],initial_epoch=60)
# Out:
# Epoch 61/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2109 - accuracy: 0.9269 - val_loss: 0.4283 - val_accuracy: 0.8654
# Epoch 62/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2203 - accuracy: 0.9260 - val_loss: 0.1643 - val_accuracy: 0.9441
# Epoch 63/100
# 687/687 [==============================] - 16s 23ms/step - loss: 0.2214 - accuracy: 0.9251 - val_loss: 0.3056 - val_accuracy: 0.8989
# Epoch 64/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2130 - accuracy: 0.9281 - val_loss: 0.1551 - val_accuracy: 0.9472
# Epoch 65/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2084 - accuracy: 0.9317 - val_loss: 0.2858 - val_accuracy: 0.9069
# Epoch 66/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1989 - accuracy: 0.9333 - val_loss: 0.2080 - val_accuracy: 0.9330
# Epoch 67/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2083 - accuracy: 0.9284 - val_loss: 0.2921 - val_accuracy: 0.9037
# Epoch 68/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2124 - accuracy: 0.9291 - val_loss: 0.2001 - val_accuracy: 0.9344
# Epoch 69/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2088 - accuracy: 0.9292 - val_loss: 0.1908 - val_accuracy: 0.9375
# Epoch 70/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.2146 - accuracy: 0.9267 - val_loss: 0.1400 - val_accuracy: 0.9572
# Epoch 71/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2025 - accuracy: 0.9311 - val_loss: 0.7603 - val_accuracy: 0.8037
# Epoch 72/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1973 - accuracy: 0.9328 - val_loss: 0.5609 - val_accuracy: 0.8383
# Epoch 73/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1966 - accuracy: 0.9332 - val_loss: 0.1286 - val_accuracy: 0.9588
# Epoch 74/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1995 - accuracy: 0.9333 - val_loss: 0.3403 - val_accuracy: 0.8920
# Epoch 75/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1970 - accuracy: 0.9344 - val_loss: 0.3291 - val_accuracy: 0.8858
# Epoch 76/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.2004 - accuracy: 0.9326 - val_loss: 0.3362 - val_accuracy: 0.8946
# Epoch 77/100
# 687/687 [==============================] - 15s 21ms/step - loss: 0.1811 - accuracy: 0.9393 - val_loss: 0.1356 - val_accuracy: 0.9576
# Epoch 78/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1951 - accuracy: 0.9344 - val_loss: 0.1675 - val_accuracy: 0.9414
# Epoch 79/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1956 - accuracy: 0.9365 - val_loss: 0.1158 - val_accuracy: 0.9598
# Epoch 80/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1934 - accuracy: 0.9347 - val_loss: 0.3372 - val_accuracy: 0.8922
# Epoch 81/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1954 - accuracy: 0.9342 - val_loss: 0.2480 - val_accuracy: 0.9177
# Epoch 82/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1911 - accuracy: 0.9354 - val_loss: 0.2689 - val_accuracy: 0.9126
# Epoch 83/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1840 - accuracy: 0.9388 - val_loss: 0.2668 - val_accuracy: 0.9146
# Epoch 84/100
# 687/687 [==============================] - 15s 21ms/step - loss: 0.1889 - accuracy: 0.9359 - val_loss: 0.0734 - val_accuracy: 0.9751
# Epoch 85/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1824 - accuracy: 0.9396 - val_loss: 0.1683 - val_accuracy: 0.9439
# Epoch 86/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1805 - accuracy: 0.9398 - val_loss: 0.1354 - val_accuracy: 0.9508
# Epoch 87/100
# 687/687 [==============================] - 16s 23ms/step - loss: 0.1895 - accuracy: 0.9362 - val_loss: 0.2687 - val_accuracy: 0.9191
# Epoch 88/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1780 - accuracy: 0.9413 - val_loss: 0.4257 - val_accuracy: 0.8630
# Epoch 89/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1860 - accuracy: 0.9376 - val_loss: 0.1281 - val_accuracy: 0.9557
# Epoch 90/100
# 687/687 [==============================] - 15s 21ms/step - loss: 0.1787 - accuracy: 0.9389 - val_loss: 0.3313 - val_accuracy: 0.9013
# Epoch 91/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1749 - accuracy: 0.9406 - val_loss: 0.2089 - val_accuracy: 0.9306
# Epoch 92/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1817 - accuracy: 0.9394 - val_loss: 0.1668 - val_accuracy: 0.9441
# Epoch 93/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1830 - accuracy: 0.9380 - val_loss: 0.2095 - val_accuracy: 0.9310
# Epoch 94/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1837 - accuracy: 0.9384 - val_loss: 0.1127 - val_accuracy: 0.9618
# Epoch 95/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1829 - accuracy: 0.9384 - val_loss: 0.6548 - val_accuracy: 0.8230
# Epoch 96/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1764 - accuracy: 0.9402 - val_loss: 0.0912 - val_accuracy: 0.9700
# Epoch 97/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1726 - accuracy: 0.9425 - val_loss: 0.1098 - val_accuracy: 0.9619
# Epoch 98/100
# 687/687 [==============================] - 15s 21ms/step - loss: 0.1704 - accuracy: 0.9403 - val_loss: 0.2676 - val_accuracy: 0.9060
# Epoch 99/100
# 687/687 [==============================] - 14s 21ms/step - loss: 0.1658 - accuracy: 0.9435 - val_loss: 0.0816 - val_accuracy: 0.9729
# Epoch 100/100
# 687/687 [==============================] - 14s 20ms/step - loss: 0.1581 - accuracy: 0.9465 - val_loss: 0.0815 - val_accuracy: 0.9740

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# Out:
# <ipython-input-23-3869c0eee6ae>:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print("test accuracy: "+ str(model.evaluate_generator(testdata_generator)[1]*100))
# test accuracy: 99.19130206108093
